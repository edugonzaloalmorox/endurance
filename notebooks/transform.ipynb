# %%
pip install skimpy
# Out:
# Collecting skimpy
#   Using cached skimpy-0.0.11-py3-none-any.whl (16 kB)
# Requirement already satisfied: Pygments<3.0.0,>=2.10.0 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from skimpy) (2.16.1)
# Collecting click<9.0.0,>=8.1.6
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Requirement already satisfied: ipykernel<7.0.0,>=6.7.0 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from skimpy) (6.26.0)
# Collecting jupyter<2.0.0,>=1.0.0
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.22.2 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from skimpy) (1.26.1)
# Requirement already satisfied: pandas<3.0.0,>=2.0.3 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from skimpy) (2.1.2)
# Collecting polars<0.20.0,>=0.19.0
#   Downloading polars-0.19.14-cp38-abi3-macosx_11_0_arm64.whl (23.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.6/23.6 MB 8.9 MB/s eta 0:00:0000:0100:01
# Collecting pyarrow<14.0.0,>=13.0.0
#   Using cached pyarrow-13.0.0-cp311-cp311-macosx_11_0_arm64.whl (23.6 MB)
# Collecting rich<14.0,>=10.9
#   Downloading rich-13.7.0-py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.6/240.6 kB 5.6 MB/s eta 0:00:00a 0:00:01
# Collecting typeguard==4.1.4
#   Using cached typeguard-4.1.4-py3-none-any.whl (34 kB)
# Collecting typing-extensions>=4.7.0
#   Using cached typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Requirement already satisfied: appnope in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (0.1.3)
# Requirement already satisfied: comm>=0.1.1 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (8.17.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (8.5.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (5.5.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (0.1.6)
# Requirement already satisfied: nest-asyncio in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (1.5.8)
# Requirement already satisfied: packaging in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (23.2)
# Requirement already satisfied: psutil in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (5.9.6)
# Requirement already satisfied: pyzmq>=20 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (25.1.1)
# Requirement already satisfied: tornado>=6.1 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (6.3.3)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (5.13.0)
# Collecting notebook
#   Downloading notebook-7.0.6-py3-none-any.whl (4.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 5.7 MB/s eta 0:00:0000:0100:01
# Collecting qtconsole
#   Downloading qtconsole-5.5.1-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 kB 8.5 MB/s eta 0:00:00
# Collecting jupyter-console
#   Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Collecting nbconvert
#   Downloading nbconvert-7.11.0-py3-none-any.whl (256 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.6/256.6 kB 10.7 MB/s eta 0:00:00
# Collecting ipywidgets
#   Using cached ipywidgets-8.1.1-py3-none-any.whl (139 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from pandas<3.0.0,>=2.0.3->skimpy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from pandas<3.0.0,>=2.0.3->skimpy) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from pandas<3.0.0,>=2.0.3->skimpy) (2023.3)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Requirement already satisfied: decorator in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.19.1)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (3.0.39)
# Requirement already satisfied: stack-data in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (4.8.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel<7.0.0,>=6.7.0->skimpy) (3.11.0)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: six>=1.5 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.0.3->skimpy) (1.16.0)
# Collecting widgetsnbextension~=4.0.9
#   Using cached widgetsnbextension-4.0.9-py3-none-any.whl (2.3 MB)
# Collecting jupyterlab-widgets~=3.0.9
#   Using cached jupyterlab_widgets-3.0.9-py3-none-any.whl (214 kB)
# Requirement already satisfied: beautifulsoup4 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (4.12.2)
# Collecting bleach!=5.0.0
#   Downloading bleach-6.1.0-py3-none-any.whl (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.8/162.8 kB 9.2 MB/s eta 0:00:00
# Collecting defusedxml
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting jinja2>=3.0
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting jupyterlab-pygments
#   Using cached jupyterlab_pygments-0.2.2-py2.py3-none-any.whl (21 kB)
# Collecting markupsafe>=2.0
#   Using cached MarkupSafe-2.1.3-cp311-cp311-macosx_10_9_universal2.whl (17 kB)
# Collecting mistune<4,>=2.0.3
#   Downloading mistune-3.0.2-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 5.5 MB/s eta 0:00:00
# Collecting nbclient>=0.5.0
#   Downloading nbclient-0.9.0-py3-none-any.whl (24 kB)
# Collecting nbformat>=5.7
#   Using cached nbformat-5.9.2-py3-none-any.whl (77 kB)
# Collecting pandocfilters>=1.4.1
#   Using cached pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Collecting tinycss2
#   Using cached tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Collecting jupyter-server<3,>=2.4.0
#   Downloading jupyter_server-2.10.1-py3-none-any.whl (378 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 378.6/378.6 kB 7.1 MB/s eta 0:00:00a 0:00:01
# Collecting jupyterlab-server<3,>=2.22.1
#   Downloading jupyterlab_server-2.25.2-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 5.0 MB/s eta 0:00:00
# Collecting jupyterlab<5,>=4.0.2
#   Downloading jupyterlab-4.0.9-py3-none-any.whl (9.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 9.2 MB/s eta 0:00:0000:0100:01m
# Collecting notebook-shim<0.3,>=0.2
#   Using cached notebook_shim-0.2.3-py3-none-any.whl (13 kB)
# Collecting qtpy>=2.4.0
#   Downloading QtPy-2.4.1-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 8.8 MB/s eta 0:00:00
# Collecting webencodings
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.8.3)
# Collecting anyio>=3.1.0
#   Downloading anyio-4.0.0-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 7.7 MB/s eta 0:00:00
# Collecting argon2-cffi
#   Using cached argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Collecting jupyter-events>=0.9.0
#   Downloading jupyter_events-0.9.0-py3-none-any.whl (18 kB)
# Collecting jupyter-server-terminals
#   Using cached jupyter_server_terminals-0.4.4-py3-none-any.whl (13 kB)
# Collecting overrides
#   Using cached overrides-7.4.0-py3-none-any.whl (17 kB)
# Collecting prometheus-client
#   Downloading prometheus_client-0.18.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 9.0 MB/s eta 0:00:00
# Collecting send2trash>=1.8.2
#   Using cached Send2Trash-1.8.2-py3-none-any.whl (18 kB)
# Collecting terminado>=0.8.3
#   Downloading terminado-0.18.0-py3-none-any.whl (14 kB)
# Collecting websocket-client
#   Downloading websocket_client-1.6.4-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 6.3 MB/s eta 0:00:00
# Collecting async-lru>=1.0.0
#   Using cached async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Collecting jupyter-lsp>=2.0.0
#   Using cached jupyter_lsp-2.2.0-py3-none-any.whl (65 kB)
# Collecting babel>=2.10
#   Downloading Babel-2.13.1-py3-none-any.whl (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 7.9 MB/s eta 0:00:0000:010:01m
# Collecting json5>=0.9.0
#   Using cached json5-0.9.14-py2.py3-none-any.whl (19 kB)
# Collecting jsonschema>=4.18.0
#   Downloading jsonschema-4.20.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.7/84.7 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.31 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (2.31.0)
# Collecting fastjsonschema
#   Downloading fastjsonschema-2.19.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.9)
# Requirement already satisfied: soupsieve>1.2 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from beautifulsoup4->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (2.5)
# Requirement already satisfied: executing>=1.2.0 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.2)
# Requirement already satisfied: idna>=2.8 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (3.4)
# Collecting sniffio>=1.1
#   Using cached sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting attrs>=22.2.0
#   Using cached attrs-23.1.0-py3-none-any.whl (61 kB)
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading jsonschema_specifications-2023.11.1-py3-none-any.whl (17 kB)
# Collecting referencing>=0.28.4
#   Downloading referencing-0.31.0-py3-none-any.whl (25 kB)
# Collecting rpds-py>=0.7.1
#   Downloading rpds_py-0.13.0-cp311-cp311-macosx_11_0_arm64.whl (327 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.1/327.1 kB 10.1 MB/s eta 0:00:00
# Collecting python-json-logger>=2.0.4
#   Using cached python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Collecting pyyaml>=5.3
#   Using cached PyYAML-6.0.1-cp311-cp311-macosx_11_0_arm64.whl (167 kB)
# Collecting rfc3339-validator
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting rfc3986-validator>=0.1.1
#   Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/personas/Dropbox/side_projects/github/endurance/endurance/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (2023.7.22)
# Collecting argon2-cffi-bindings
#   Using cached argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl (53 kB)
# Collecting fqdn
#   Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting isoduration
#   Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting jsonpointer>1.13
#   Using cached jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Collecting uri-template
#   Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Collecting webcolors>=1.11
#   Using cached webcolors-1.13-py3-none-any.whl (14 kB)
# Collecting cffi>=1.0.1
#   Downloading cffi-1.16.0-cp311-cp311-macosx_11_0_arm64.whl (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.7/176.7 kB 8.2 MB/s eta 0:00:00
# Collecting pycparser
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting arrow>=0.15.0
#   Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 9.8 MB/s eta 0:00:00
# Collecting types-python-dateutil>=2.8.10
#   Downloading types_python_dateutil-2.8.19.14-py3-none-any.whl (9.4 kB)
# Installing collected packages: webencodings, types-python-dateutil, json5, fastjsonschema, widgetsnbextension, websocket-client, webcolors, uri-template, typing-extensions, tinycss2, terminado, sniffio, send2trash, rpds-py, rfc3986-validator, rfc3339-validator, qtpy, pyyaml, python-json-logger, pycparser, pyarrow, prometheus-client, polars, pandocfilters, overrides, mistune, mdurl, markupsafe, jupyterlab-widgets, jupyterlab-pygments, jsonpointer, fqdn, defusedxml, click, bleach, babel, attrs, async-lru, typeguard, referencing, markdown-it-py, jupyter-server-terminals, jinja2, cffi, arrow, anyio, rich, jsonschema-specifications, isoduration, argon2-cffi-bindings, jsonschema, ipywidgets, argon2-cffi, qtconsole, nbformat, jupyter-console, nbclient, jupyter-events, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter, skimpy
# Successfully installed anyio-4.0.0 argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.4 attrs-23.1.0 babel-2.13.1 bleach-6.1.0 cffi-1.16.0 click-8.1.7 defusedxml-0.7.1 fastjsonschema-2.19.0 fqdn-1.5.1 ipywidgets-8.1.1 isoduration-20.11.0 jinja2-3.1.2 json5-0.9.14 jsonpointer-2.4 jsonschema-4.20.0 jsonschema-specifications-2023.11.1 jupyter-1.0.0 jupyter-console-6.6.3 jupyter-events-0.9.0 jupyter-lsp-2.2.0 jupyter-server-2.10.1 jupyter-server-terminals-0.4.4 jupyterlab-4.0.9 jupyterlab-pygments-0.2.2 jupyterlab-server-2.25.2 jupyterlab-widgets-3.0.9 markdown-it-py-3.0.0 markupsafe-2.1.3 mdurl-0.1.2 mistune-3.0.2 nbclient-0.9.0 nbconvert-7.11.0 nbformat-5.9.2 notebook-7.0.6 notebook-shim-0.2.3 overrides-7.4.0 pandocfilters-1.5.0 polars-0.19.14 prometheus-client-0.18.0 pyarrow-13.0.0 pycparser-2.21 python-json-logger-2.0.7 pyyaml-6.0.1 qtconsole-5.5.1 qtpy-2.4.1 referencing-0.31.0 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rich-13.7.0 rpds-py-0.13.0 send2trash-1.8.2 skimpy-0.0.11 sniffio-1.3.0 terminado-0.18.0 tinycss2-1.2.1 typeguard-4.1.4 types-python-dateutil-2.8.19.14 typing-extensions-4.8.0 uri-template-1.3.0 webcolors-1.13 webencodings-0.5.1 websocket-client-1.6.4 widgetsnbextension-4.0.9
#
# [notice] A new release of pip is available: 23.0.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from skimpy import skim
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Clean bikepacking.com info

# %%
bikepacking = pd.read_csv('data/df_endurance.csv')
bikepacking.head(10)
# Out:
#                 Name Age      Country  \
# 0      Miron Golfman  30          USA
# 1       Matt Annabel  48          USA
# 2      Ryan Bartelme  36          USA
# 3    Thomas Duehrsen  52  Switzerland
# 4      Elliot DuMont  35          USA
# 5  Johnny Fitzgerald  36          USA
# 6    Zack Freundlich  36          USA
# 7     Matan Guttmann  25       Canada
# 8       Jason Hanson  51          USA
# 9    Jennifer Hanson  56          USA
#
#                                      Location  \
# 0                      Anchorage Alaska (USA)
# 1                  Carbondale, Colorado (USA)
# 2                       Tucson, Arizona (USA)
# 3                          Thun (Switzerland)
# 4                       Tucson, Arizona (USA)
# 5                       Helena, Montana (USA)
# 6                         McCall, Idaho (USA)
# 7  North Vancouver, British Columbia (Canada)
# 8                     Florence, Arizona (USA)
# 9                     Florence, Arizona (USA)
#
#                                                 Bike  \
# 0  I’m riding a Santa Cruz Blur, with SRAM XO1 dr...
# 1  I’ll be piloting “Badger,” my singlespeed Why ...
# 2  I’ll be riding AZTR300 on a 2021 Yeti SB130 CL...
# 3  2022 ToutTerrain Outback 27.5 steel with Pinio...
# 4  Soma Juice, Shimano 1×12 (30T chainring), home...
# 5  I’ll be riding a Niner SIR 9 hardtail. This bi...
# 6  Esker Hayduke Ti, Pike 130, DT Swiss EX Wheels...
# 7  I will be riding a 2018 Salsa Timberjack, newl...
# 8  Binary SuperBxc, NOX Wheels with Industry Nine...
# 9  Salsa Spearfish, 1×12 SRAM drivetrain with 26T...
#
#                                                 Bags  \
# 0  DTF dreams custom handlebar bag, Woolf Tooth b...
# 1  A much loved Rogue Panda Canelo bar-harness le...
# 2  If Miles issues an award for bike bag hacks, I...
# 3  Made myself a HF welded framebag from PVC coat...
# 4  Bags by Revelate, Nuclear Sunrise, Diday, and ...
# 5  It’s a mixed bag. Defiant frame bag that is cu...
# 6                 Dispersed, Rockgeist, Rogue Panda.
# 7  Custom Rogue Panda frame bag. Rockgeist Mr. Fu...
# 8  Broadfork frame bag, Rogue Panda gas tank bag,...
# 9  Rogue Panda frame bag, top tube bag and gas ta...
#
#                                                 Gear    Route  \
# 0  KLite Ultra Racing Lighting System w/ Bar swit...  No info
# 1  The dynamo has one job: to juice my Garmin 104...  No info
# 2  I brought a small stove for hot coffee and oat...  No info
# 3  My Pedalcell broke shortly before the trip and...  No info
# 4  My trusty Brooks B17 saddle and a Mystery Ranc...  No info
# 5  Bandana for sun cover and cooling. MSR Trail S...  No info
# 6  kLite Ultra, Fenix Lights, King Cage, GG Blaze...  No info
# 7  I will be wearing a Salomon Active 8 vest and ...  No info
# 8       Redshift seat post and Sea to Summit pillow.  No info
# 9  Xerocole Desert hiking boots and Tectonic flat...  No info
#
#                                  Race  \
# 0  the 2023 Arizona Trail Race (AZTR)
# 1  the 2023 Arizona Trail Race (AZTR)
# 2  the 2023 Arizona Trail Race (AZTR)
# 3  the 2023 Arizona Trail Race (AZTR)
# 4  the 2023 Arizona Trail Race (AZTR)
# 5  the 2023 Arizona Trail Race (AZTR)
# 6  the 2023 Arizona Trail Race (AZTR)
# 7  the 2023 Arizona Trail Race (AZTR)
# 8  the 2023 Arizona Trail Race (AZTR)
# 9  the 2023 Arizona Trail Race (AZTR)
#
#                                                 Link
# 0  https://bikepacking.com/bikes/2023-arizona-tra...
# 1  https://bikepacking.com/bikes/2023-arizona-tra...
# 2  https://bikepacking.com/bikes/2023-arizona-tra...
# 3  https://bikepacking.com/bikes/2023-arizona-tra...
# 4  https://bikepacking.com/bikes/2023-arizona-tra...
# 5  https://bikepacking.com/bikes/2023-arizona-tra...
# 6  https://bikepacking.com/bikes/2023-arizona-tra...
# 7  https://bikepacking.com/bikes/2023-arizona-tra...
# 8  https://bikepacking.com/bikes/2023-arizona-tra...
# 9  https://bikepacking.com/bikes/2023-arizona-tra...

# %% [markdown]
# ### Clean names of races

# %%
# Make column names lowercase

bikepacking.columns = bikepacking.columns.str.lower()

# %%
# Make age column numeric

bikepacking['age'] = pd.to_numeric(bikepacking['age'], errors='coerce')

# %%
bikepacking['race'] = bikepacking['race'].str.replace('the', '')
bikepacking['race'] = bikepacking['race'].str.replace('The', '')

# %%
bikepacking.head(10)
# Out:
#                 name   age      country  \
# 0      Miron Golfman  30.0          USA
# 1       Matt Annabel  48.0          USA
# 2      Ryan Bartelme  36.0          USA
# 3    Thomas Duehrsen  52.0  Switzerland
# 4      Elliot DuMont  35.0          USA
# 5  Johnny Fitzgerald  36.0          USA
# 6    Zack Freundlich  36.0          USA
# 7     Matan Guttmann  25.0       Canada
# 8       Jason Hanson  51.0          USA
# 9    Jennifer Hanson  56.0          USA
#
#                                      location  \
# 0                      Anchorage Alaska (USA)
# 1                  Carbondale, Colorado (USA)
# 2                       Tucson, Arizona (USA)
# 3                          Thun (Switzerland)
# 4                       Tucson, Arizona (USA)
# 5                       Helena, Montana (USA)
# 6                         McCall, Idaho (USA)
# 7  North Vancouver, British Columbia (Canada)
# 8                     Florence, Arizona (USA)
# 9                     Florence, Arizona (USA)
#
#                                                 bike  \
# 0  I’m riding a Santa Cruz Blur, with SRAM XO1 dr...
# 1  I’ll be piloting “Badger,” my singlespeed Why ...
# 2  I’ll be riding AZTR300 on a 2021 Yeti SB130 CL...
# 3  2022 ToutTerrain Outback 27.5 steel with Pinio...
# 4  Soma Juice, Shimano 1×12 (30T chainring), home...
# 5  I’ll be riding a Niner SIR 9 hardtail. This bi...
# 6  Esker Hayduke Ti, Pike 130, DT Swiss EX Wheels...
# 7  I will be riding a 2018 Salsa Timberjack, newl...
# 8  Binary SuperBxc, NOX Wheels with Industry Nine...
# 9  Salsa Spearfish, 1×12 SRAM drivetrain with 26T...
#
#                                                 bags  \
# 0  DTF dreams custom handlebar bag, Woolf Tooth b...
# 1  A much loved Rogue Panda Canelo bar-harness le...
# 2  If Miles issues an award for bike bag hacks, I...
# 3  Made myself a HF welded framebag from PVC coat...
# 4  Bags by Revelate, Nuclear Sunrise, Diday, and ...
# 5  It’s a mixed bag. Defiant frame bag that is cu...
# 6                 Dispersed, Rockgeist, Rogue Panda.
# 7  Custom Rogue Panda frame bag. Rockgeist Mr. Fu...
# 8  Broadfork frame bag, Rogue Panda gas tank bag,...
# 9  Rogue Panda frame bag, top tube bag and gas ta...
#
#                                                 gear    route  \
# 0  KLite Ultra Racing Lighting System w/ Bar swit...  No info
# 1  The dynamo has one job: to juice my Garmin 104...  No info
# 2  I brought a small stove for hot coffee and oat...  No info
# 3  My Pedalcell broke shortly before the trip and...  No info
# 4  My trusty Brooks B17 saddle and a Mystery Ranc...  No info
# 5  Bandana for sun cover and cooling. MSR Trail S...  No info
# 6  kLite Ultra, Fenix Lights, King Cage, GG Blaze...  No info
# 7  I will be wearing a Salomon Active 8 vest and ...  No info
# 8       Redshift seat post and Sea to Summit pillow.  No info
# 9  Xerocole Desert hiking boots and Tectonic flat...  No info
#
#                               race  \
# 0   2023 Arizona Trail Race (AZTR)
# 1   2023 Arizona Trail Race (AZTR)
# 2   2023 Arizona Trail Race (AZTR)
# 3   2023 Arizona Trail Race (AZTR)
# 4   2023 Arizona Trail Race (AZTR)
# 5   2023 Arizona Trail Race (AZTR)
# 6   2023 Arizona Trail Race (AZTR)
# 7   2023 Arizona Trail Race (AZTR)
# 8   2023 Arizona Trail Race (AZTR)
# 9   2023 Arizona Trail Race (AZTR)
#
#                                                 link
# 0  https://bikepacking.com/bikes/2023-arizona-tra...
# 1  https://bikepacking.com/bikes/2023-arizona-tra...
# 2  https://bikepacking.com/bikes/2023-arizona-tra...
# 3  https://bikepacking.com/bikes/2023-arizona-tra...
# 4  https://bikepacking.com/bikes/2023-arizona-tra...
# 5  https://bikepacking.com/bikes/2023-arizona-tra...
# 6  https://bikepacking.com/bikes/2023-arizona-tra...
# 7  https://bikepacking.com/bikes/2023-arizona-tra...
# 8  https://bikepacking.com/bikes/2023-arizona-tra...
# 9  https://bikepacking.com/bikes/2023-arizona-tra...

# %%
bikepacking['race'].unique()
# Out:
# array([' 2023 Arizona Trail Race (AZTR)',
#        ' 2023 Arkansas High Country Race', ' 2023 Badland',
#        ' 2023 Colorado Trail Race',
#        ' 2023 Silk Road Mountain Race (SRMR)',
#        ' 2023 Ascend Armenia + Event Backstory',
#        '2023 Rigs of  Tour Divide Breakdown: Stats Analysis…',
#        ' 2023 Tour Divide (Part 2): Flat-Bar Bike',
#        ' 2023 Tour Divide (Part 1): Drop-Bar Bike',
#        ' 2023 Trans Balkan Race', ' 2023 Highland Trail 550 (HT550)',
#        ' 2023 Pinyons and Pine', ' 2023 Hellenic Mountain Race',
#        ' 2023 Stagecoach 400', ' 2022 Klunk ‘n’ Float',
#        ' 2023 Iditarod Trail Invitational', ' 2023 Atlas Mountain Race',
#        ' 2022 Hunt 1000 (Spring Depart)',
#        ' 2022 Arizona Trail Race (AZTR)',
#        ' 2022 Arkansas High Country Race', ' 2022 Atlas Mountain Race',
#        ' 2022 Badland', ' 2022 Trans North Georgia Adventure (TNGA)',
#        ' 2022 Colorado Trail Race',
#        ' 2022 Silk Road Mountain Race (SRMR)',
#        ' 2022 Transcontinental Race No.8',
#        ' 2022 Tour Divide (Part 2): Drop-Bar Bike',
#        ' 2022 Tour Divide (Part 1): Flat-Bar Bike',
#        ' 2022 Trans Balkan Race', ' 2022 Highland Trail 550 (HT550)',
#        ' 2022 Pinyons & Pine', ' 2022 Stagecoach 400', ' 2022 Hunt 1000',
#        ' 2022 Huracan Challenge', ' 2021 Arizona Trail Race (AZTR)',
#        ' 2021 Hungarian Divide', ' 2021 Badland',
#        ' 2021 Trans North Georgia Adventure (TNGA)',
#        ' 2021 Silk Road Mountain Race', ' 2021 Colorado Trail Race (CTR)',
#        ' 2021 Veneto Trail', ' 2021 Oregon Timber Trail',
#        'Lael Wilcox and her 2021 Hope 1000 Race', ' 2021 Tour Divide',
#        'Two Rigs of  HT550', ' Badlands 2020',
#        ' 2020 Atlas Mountain Race', ' 2019 Adirondack Trail Ride (TATR)',
#        ' 2019 Silk Road Mountain Race', ' 2019 Colorado Trail Race (CTR)',
#        ' 2019 Tour Divide', ' 2018 TNGA', ' 2018 BC Epic 1000',
#        ' 2018 Tour Divide'], dtype=object)

# %%
bikepacking['source'] = 'bikepacking.com'
bikepacking.head(10)
# Out:
#                 name age      country  \
# 0      Miron Golfman  30          USA
# 1       Matt Annabel  48          USA
# 2      Ryan Bartelme  36          USA
# 3    Thomas Duehrsen  52  Switzerland
# 4      Elliot DuMont  35          USA
# 5  Johnny Fitzgerald  36          USA
# 6    Zack Freundlich  36          USA
# 7     Matan Guttmann  25       Canada
# 8       Jason Hanson  51          USA
# 9    Jennifer Hanson  56          USA
#
#                                      location  \
# 0                      Anchorage Alaska (USA)
# 1                  Carbondale, Colorado (USA)
# 2                       Tucson, Arizona (USA)
# 3                          Thun (Switzerland)
# 4                       Tucson, Arizona (USA)
# 5                       Helena, Montana (USA)
# 6                         McCall, Idaho (USA)
# 7  North Vancouver, British Columbia (Canada)
# 8                     Florence, Arizona (USA)
# 9                     Florence, Arizona (USA)
#
#                                                 bike  \
# 0  I’m riding a Santa Cruz Blur, with SRAM XO1 dr...
# 1  I’ll be piloting “Badger,” my singlespeed Why ...
# 2  I’ll be riding AZTR300 on a 2021 Yeti SB130 CL...
# 3  2022 ToutTerrain Outback 27.5 steel with Pinio...
# 4  Soma Juice, Shimano 1×12 (30T chainring), home...
# 5  I’ll be riding a Niner SIR 9 hardtail. This bi...
# 6  Esker Hayduke Ti, Pike 130, DT Swiss EX Wheels...
# 7  I will be riding a 2018 Salsa Timberjack, newl...
# 8  Binary SuperBxc, NOX Wheels with Industry Nine...
# 9  Salsa Spearfish, 1×12 SRAM drivetrain with 26T...
#
#                                                 bags  \
# 0  DTF dreams custom handlebar bag, Woolf Tooth b...
# 1  A much loved Rogue Panda Canelo bar-harness le...
# 2  If Miles issues an award for bike bag hacks, I...
# 3  Made myself a HF welded framebag from PVC coat...
# 4  Bags by Revelate, Nuclear Sunrise, Diday, and ...
# 5  It’s a mixed bag. Defiant frame bag that is cu...
# 6                 Dispersed, Rockgeist, Rogue Panda.
# 7  Custom Rogue Panda frame bag. Rockgeist Mr. Fu...
# 8  Broadfork frame bag, Rogue Panda gas tank bag,...
# 9  Rogue Panda frame bag, top tube bag and gas ta...
#
#                                                 gear    route  \
# 0  KLite Ultra Racing Lighting System w/ Bar swit...  No info
# 1  The dynamo has one job: to juice my Garmin 104...  No info
# 2  I brought a small stove for hot coffee and oat...  No info
# 3  My Pedalcell broke shortly before the trip and...  No info
# 4  My trusty Brooks B17 saddle and a Mystery Ranc...  No info
# 5  Bandana for sun cover and cooling. MSR Trail S...  No info
# 6  kLite Ultra, Fenix Lights, King Cage, GG Blaze...  No info
# 7  I will be wearing a Salomon Active 8 vest and ...  No info
# 8       Redshift seat post and Sea to Summit pillow.  No info
# 9  Xerocole Desert hiking boots and Tectonic flat...  No info
#
#                               race  \
# 0   2023 Arizona Trail Race (AZTR)
# 1   2023 Arizona Trail Race (AZTR)
# 2   2023 Arizona Trail Race (AZTR)
# 3   2023 Arizona Trail Race (AZTR)
# 4   2023 Arizona Trail Race (AZTR)
# 5   2023 Arizona Trail Race (AZTR)
# 6   2023 Arizona Trail Race (AZTR)
# 7   2023 Arizona Trail Race (AZTR)
# 8   2023 Arizona Trail Race (AZTR)
# 9   2023 Arizona Trail Race (AZTR)
#
#                                                 link           source
# 0  https://bikepacking.com/bikes/2023-arizona-tra...  bikepacking.com
# 1  https://bikepacking.com/bikes/2023-arizona-tra...  bikepacking.com
# 2  https://bikepacking.com/bikes/2023-arizona-tra...  bikepacking.com
# 3  https://bikepacking.com/bikes/2023-arizona-tra...  bikepacking.com
# 4  https://bikepacking.com/bikes/2023-arizona-tra...  bikepacking.com
# 5  https://bikepacking.com/bikes/2023-arizona-tra...  bikepacking.com
# 6  https://bikepacking.com/bikes/2023-arizona-tra...  bikepacking.com
# 7  https://bikepacking.com/bikes/2023-arizona-tra...  bikepacking.com
# 8  https://bikepacking.com/bikes/2023-arizona-tra...  bikepacking.com
# 9  https://bikepacking.com/bikes/2023-arizona-tra...  bikepacking.com

# %%
skim(bikepacking)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 2963   │ │ string      │ 9     │                                                          │
# │ │ Number of columns │ 10     │ │ float64     │ 1     │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━┳━━━━━━┳━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┓  │
# │ ┃ column_name       ┃ NA     ┃ NA %     ┃ mean    ┃ sd   ┃ p0   ┃ p25   ┃ p50   ┃ p75   ┃ p100    ┃ hist     ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━╇━━━━━━╇━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━┩  │
# │ │ age               │    392 │    13.23 │      41 │   11 │    0 │    32 │    39 │    49 │      73 │   ▁▇▇▅▁  │  │
# │ └───────────────────┴────────┴──────────┴─────────┴──────┴──────┴───────┴───────┴───────┴─────────┴──────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name               ┃ NA      ┃ NA %       ┃ words per row                ┃ total words              ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ name                      │       0 │          0 │                          2.1 │                     6174 │  │
# │ │ country                   │       0 │          0 │                          1.3 │                     3924 │  │
# │ │ location                  │       0 │          0 │                          2.9 │                     8650 │  │
# │ │ bike                      │       0 │          0 │                           44 │                   129560 │  │
# │ │ bags                      │       1 │       0.03 │                           31 │                    90846 │  │
# │ │ gear                      │       0 │          0 │                           33 │                    98043 │  │
# │ │ route                     │       0 │          0 │                            2 │                     5944 │  │
# │ │ race                      │       0 │          0 │                          4.9 │                    14389 │  │
# │ │ link                      │       0 │          0 │                            1 │                     2963 │  │
# │ └───────────────────────────┴─────────┴────────────┴──────────────────────────────┴──────────────────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %% [markdown]
# ## Clean dotwatcher.cc

# %%
dotwatch = pd.read_csv('data/df_dotwatch.csv')
dotwatch.columns = dotwatch.columns.str.lower()
dotwatch.head(5)
# Out:
#               name      race                                             link  \
# 0   Nils Opgenorth  GBDURO23  https://dotwatcher.cc/feature/bikes-of-gbduro23
# 1         Tom Hall  GBDURO23  https://dotwatcher.cc/feature/bikes-of-gbduro23
# 2  Jordan Matthews  GBDURO23  https://dotwatcher.cc/feature/bikes-of-gbduro23
# 3    Chris Ellison  GBDURO23  https://dotwatcher.cc/feature/bikes-of-gbduro23
# 4       Tim Taylor  GBDURO23  https://dotwatcher.cc/feature/bikes-of-gbduro23
#
#     age                   location  \
# 0  27.0         Stuttgart, Germany
# 1  42.0                 Sussex, UK
# 2  30.0             Sunderland, UK
# 3  60.0  Austwick, Yorkshire Dales
# 4  48.0           Warwickshire, UK
#
#                                                 bike  \
# 0  I will be riding the GBDURO23 with my beloved ...
# 1  Mason Bokeh mk.1 with Hunt 650b dynamo wheel set.
# 2  Fairlight Secan, GRX X2, Hunt Dynamo Wheelset ...
# 3  I’ll be riding the GBDuro23 on my Salsa Cutthr...
# 4  Kinesis GTD v2 (aka 'Goat HeaD'), mostly Shima...
#
#                                     key items of kit  \
# 0  I spent some time organising the front of the ...
# 1  Apidura rig, 7l seat pack, frame pack, long to...
# 2  Alpkit, Ortlieb and Straight Cut bags.\nTent, ...
# 3  Much of my cold weather down and sleep gear is...
# 4  Re-strap and Apidura bags. Exposure lights. Sl...
#
#                        cap number          country key items of kit bike:  \
# 0                             NaN          Germany              NaN   NaN
# 1                             NaN               UK              NaN   NaN
# 2                             NaN               UK              NaN   NaN
# 3                             NaN  Yorkshire Dales              NaN   NaN
# 4  (Will be sporting a Zwift cap)               UK              NaN   NaN
#
#   key items of kit: name: age: location: bags/kit: cap number cap number:  \
# 0               NaN   NaN  NaN       NaN       NaN        NaN         NaN
# 1               NaN   NaN  NaN       NaN       NaN        NaN         NaN
# 2               NaN   NaN  NaN       NaN       NaN        NaN         NaN
# 3               NaN   NaN  NaN       NaN       NaN        NaN         NaN
# 4               NaN   NaN  NaN       NaN       NaN        NaN         NaN
#
#   bags: your bike
# 0   NaN       NaN
# 1   NaN       NaN
# 2   NaN       NaN
# 3   NaN       NaN
# 4   NaN       NaN

# %%
# Select columns from dotwatch dataframe

dotwatch = dotwatch[['name', 'age', 'country',	'location', 'bike',	'key items of kit', 'race', 'link']]
# select columns by position

# merge columns 0:6 dotwatch with columns 8:9 dotwatch

dotwatch = dotwatch.iloc[:, 0:6].merge(dotwatch.iloc[:, 7:10], left_index=True, right_index=True)
dotwatch.head(5)
# Out:
#               name   age          country                   location  \
# 0   Nils Opgenorth  27.0          Germany         Stuttgart, Germany
# 1         Tom Hall  42.0               UK                 Sussex, UK
# 2  Jordan Matthews  30.0               UK             Sunderland, UK
# 3    Chris Ellison  60.0  Yorkshire Dales  Austwick, Yorkshire Dales
# 4       Tim Taylor  48.0               UK           Warwickshire, UK
#
#                                                 bike  \
# 0  I will be riding the GBDURO23 with my beloved ...
# 1  Mason Bokeh mk.1 with Hunt 650b dynamo wheel set.
# 2  Fairlight Secan, GRX X2, Hunt Dynamo Wheelset ...
# 3  I’ll be riding the GBDuro23 on my Salsa Cutthr...
# 4  Kinesis GTD v2 (aka 'Goat HeaD'), mostly Shima...
#
#                                     key items of kit      race  \
# 0  I spent some time organising the front of the ...  GBDURO23
# 1  Apidura rig, 7l seat pack, frame pack, long to...  GBDURO23
# 2  Alpkit, Ortlieb and Straight Cut bags.\nTent, ...  GBDURO23
# 3  Much of my cold weather down and sleep gear is...  GBDURO23
# 4  Re-strap and Apidura bags. Exposure lights. Sl...  GBDURO23
#
#                                               link
# 0  https://dotwatcher.cc/feature/bikes-of-gbduro23
# 1  https://dotwatcher.cc/feature/bikes-of-gbduro23
# 2  https://dotwatcher.cc/feature/bikes-of-gbduro23
# 3  https://dotwatcher.cc/feature/bikes-of-gbduro23
# 4  https://dotwatcher.cc/feature/bikes-of-gbduro23

# %%
# select rows with missing values in country column

problem_country = dotwatch[dotwatch['country'].isnull()]

# %%
problem_country.head(5)
# Out:
#                            name   age country                 location  \
# 5                 Bryce Jersing  23.0     NaN  Oxfordshire/Uni of Bath
# 11               Alex Fthenakis  37.0     NaN                  Glasgow
# 22              federico bassis  32.0     NaN                    Italy
# 24             Henning Roalkvam  48.0     NaN                   Norway
# 27  Andrea / Bike like a couple  39.0     NaN                Istraland
#
#                                                  bike  \
# 5   Riding to raise money for Movember on my trust...
# 11  Albannach Torragar with Rodeo Spork Forks, a m...
# 22                   Basso Palta Team Enough Cycling.
# 24  Basso Palta. The bike is equipped with a SRAM ...
# 27              OPEN U.P Telaio, Campagnolo Ekar 13v.
#
#                                      key items of kit             race  \
# 5   Tailfin AeroPack: Alpkit/Decathlon-based sleep...         GBDURO23
# 11  Cyclite aero bar bag mostly for jackets, glove...         GBDURO23
# 22                                  Miss Grape packs.  Istra Land 2023
# 24           Lights are Sinewave Beacon dynamo light.  Istra Land 2023
# 27  Ruote Hed Emporia, Sella Fizik Terra Argo, Por...  Istra Land 2023
#
#                                                  link
# 5     https://dotwatcher.cc/feature/bikes-of-gbduro23
# 11    https://dotwatcher.cc/feature/bikes-of-gbduro23
# 22  https://dotwatcher.cc/feature/bikes-of-istra-l...
# 24  https://dotwatcher.cc/feature/bikes-of-istra-l...
# 27  https://dotwatcher.cc/feature/bikes-of-istra-l...

# %%
# problem_country['location'].unique()

country_mapping = {
    'Oxfordshire/Uni of Bath': 'United Kingdom',
    'Glasgow': 'United Kingdom',
    'Italy': 'Italy',
    'Norway': 'Norway',
    'Istraland': 'Italy',  
    'Bassano del Grappa': 'Italy',
    'Bochum': 'Germany',
    'Germany': 'Germany',
    'Portugal/Luxembourg': 'Portugal',
    'NZ': 'New Zealand',
    'Slovenia': 'Slovenia',
    'Austria': 'Austria',
    'Croatia': 'Croatia',
    'London': 'United Kingdom',
    'France': 'France',
    'Girona': 'Spain',
    'South East London': 'United Kingdom',
    'Masies de Voltregà (SPAIN)': 'Spain',
    'Paris': 'France',
    'Truro': 'United Kingdom',
    'Canterbury': 'United Kingdom',
    'New Forest': 'United Kingdom',
    'Bexley': 'United Kingdom',
    'St Ives Cornwall': 'United Kingdom',
    'Warwickshire': 'United Kingdom',
    'Surrey': 'United Kingdom',
    'Falkensee (Brandenburg/GER)': 'Germany',
    'Mülheim an der Ruhr Deutschland': 'Germany',
    'Leichlingen (Germnany)': 'Germany',
    'Berlin': 'Germany',
    'Baden bei Wien': 'Austria',
    'Halstenbek': 'Germany',
    'Amsterdam': 'Netherlands',
    'Düsseldorf': 'Germany',
    'Lithuania': 'Lithuania',
    'New Zealand': 'New Zealand',
    'Ingolstadt': 'Germany',
    'Sittard (NL)': 'Netherlands',
    'Innsbruck': 'Austria',
    'Lucca': 'Italy',
    'Dresden Germany': 'Germany',
    'Rosenheim': 'Germany',
    'Jena': 'Germany',
    'Llangynidr': 'United Kingdom',
    'Durham UK': 'United Kingdom',
    'Colombia': 'Colombia',
    'Frankfurt': 'Germany',
    'Vienna': 'Austria',
    'The Netherlands': 'Netherlands',
    'Australia': 'Australia',
    'Rotterdam': 'Netherlands',
    'BIELSKO BIAŁA': 'Poland',
    'Belgium': 'Belgium',
    'Netherlands': 'Netherlands',
    'Utrecht': 'Netherlands',
    'Diemen': 'Netherlands',
    'Woerden': 'Netherlands',
    'Zeeland': 'Netherlands',
    'Köln': 'Germany',
    'Newport on Tay': 'United Kingdom',
    'Koblenz (Germany)': 'Germany',
    'Cornwall': 'United Kingdom',
    'Isle of Wight': 'United Kingdom',
    'Bury St Edmunds': 'United Kingdom',
    'South Wales': 'United Kingdom',
    'Wiltshire': 'United Kingdom',
    'Montréal': 'Canada',
    'Ottawa': 'Canada',
    'Pakenham': 'Australia',
    'Saint Sauveur': 'Canada',
    'Toronto': 'Canada',
    'Saint-Sauveur': 'Canada',
    'MONTRÉAL': 'Canada',
    'Portgruaro': 'Italy',
    'Cadiar': 'Spain',
    'The Netherlands / Amerongen': 'Netherlands',
    'Salamanca': 'Spain',
    'Windsor': 'United Kingdom',
    'Bergamo (ITA)': 'Italy',
    'Madrid': 'Spain',
    'Turkiye': 'Turkey',
    'Munich (Germany)': 'Germany',
    'Switzerland': 'Switzerland',
    "l'Alcúdia (Spain)": 'Spain',
    'Castelldefels': 'Spain',
    'Sevilla': 'Spain',
    'Toledo': 'Spain',
    'Girona (Catalunya)': 'Spain',
    'Spain': 'Spain',
    'Copenhagen': 'Denmark',
    'London (UK)': 'United Kingdom',
    'Thunder Bay Ontario Canada': 'Canada',
    'Barcelona': 'Spain',
    'Sabero (León': 'Spain',
    'Bilbao': 'Spain',
    'Valladolid': 'Spain',
    'Zaragoza': 'Spain',
    'GBR': 'United Kingdom',
    'Riaydh': 'Saudi Arabia',
    'Traunstein': 'Germany',
    'Genval Belgium': 'Belgium',
    'Tongeren': 'Belgium',
    'Venice': 'Italy',
    'Dorset': 'United Kingdom',
    'Brighton': 'United Kingdom',
    'Darkest Dorset': 'United Kingdom',
    'Kingston upon Thames': 'United Kingdom',
    'Bristol': 'United Kingdom',
    'Glossop': 'United Kingdom',
    'South Australia': 'Australia',
    'Carpi': 'Italy',
    'weil am rhein': 'Germany',
    'Holzkirchen': 'Germany',
    'London // UK': 'United Kingdom',
    'München': 'Germany',
    'Aarau': 'Switzerland',
    'LONDON': 'United Kingdom',
    'Munich': 'Germany',
    'Frankfurt (Germany)': 'Germany',
    'Poland': 'Poland',
    'Vienna Austria': 'Austria',
    'Plymouth': 'United Kingdom',
    'Rixensart - Belgium': 'Belgium',
    'Oswestry Shropshire': 'United Kingdom',
    'Darlington': 'United Kingdom',
    'Pembrokeshire': 'United Kingdom',
    'Abergele': 'United Kingdom',
    'Scarborough': 'United Kingdom',
    'East Yorkshire': 'United Kingdom',
    'North Derby': 'United Kingdom',
    'Eastbourne': 'United Kingdom',
    'Lincolnshire': 'United Kingdom',
    'Royal Leamington Spa': 'United Kingdom',
    'Oxford': 'United Kingdom',
    'Redhill': 'United Kingdom',
    'Kiruna': 'Sweden',
    'Stockholm': 'Sweden',
    'Alingsås': 'Sweden',
    'Brussels': 'Belgium',
    'California': 'United States',
    'Bavaria': 'Germany',
    'Helsinki Finland': 'Finland',
    'an Australian in London': 'Australia',
    'Leipzig/Germany': 'Germany',
    'Bend Oregon USA': 'United States',
    'Suisse': 'Switzerland',
    'Bergen': 'Norway',
    'Lausanne': 'Switzerland',
    'Leipzig': 'Germany',
    'Slovakia 🇬🇧': 'Slovakia',
    'Portugal': 'Portugal',
    'Utiel (Valencia)': 'Spain',
    'Toulouse': 'France',
    'UK': 'United Kingdom',
    'Sweden': 'Sweden',
    'MADRID': 'Spain',
    'Ariège': 'France',
    'Lyon': 'France',
    'El Prat de Llobregat': 'Spain',
    'Sopelana': 'Spain',
    'Banbury': 'United Kingdom',
    'Northants': 'United Kingdom',
    'Lincoln': 'United Kingdom',
    'Birmingham': 'United Kingdom',
    'Essex': 'United Kingdom',
    'nan': 'Unknown',
    'England': 'United Kingdom',
    'Manchester': 'United Kingdom',
    "'t Harde NL": 'Netherlands',
    'Harrogate UK': 'United Kingdom',
    'Aalsmeer The Netherlands': 'Netherlands',
    'Purmerend Netherlands': 'Netherlands',
    'Driebergen-Rijsenburg': 'Netherlands',
    'Nederland': 'Netherlands',
    'Deutschland': 'Germany',
    'Heusden-Zolder (Belgium)': 'Belgium',
    'Wehrheim / Germany': 'Germany',
    'Schöneck / Germany': 'Germany',
    'Merelbeke': 'Belgium',
    'Hereford': 'United Kingdom',
    'Shropshire': 'United Kingdom',
    'Cardiff': 'United Kingdom',
    'Wales': 'United Kingdom',
    'Romsey': 'United Kingdom',
    'Malvern': 'United Kingdom',
    'Slovenija': 'Slovenia',
    'Italy.Roma': 'Italy',
    'Farndon UK': 'United Kingdom',
    'Derventa BiH': 'Bosnia and Herzegovina',
    'Las Palmas de Gran Canaria': 'Spain',
    'Versailles France': 'France',
    'Banja Luka': 'Bosnia and Herzegovina',
    'Athens Greece': 'Greece',
    'Gernany': 'Germany',
    'Vienna/Austria': 'Austria',
    'Köln / Germany': 'Germany',
    'Frankfurt am Main': 'Germany',
    'Trieste': 'Italy',
    'Auerbach/Germany': 'Germany',
    'Luebeck': 'Germany',
    'Eindhoven': 'Netherlands',
    'Czech Republic': 'Czech Republic',
    'Chelmsford': 'United Kingdom',
    'Down south': 'Unknown',
    'West sussex': 'United Kingdom',
    'Twickenham': 'United Kingdom',
    'Colchester,': 'United Kingdom',
    'High Wycombe': 'United Kingdom',
    'London UK': 'United Kingdom',
    'Whitstable': 'United Kingdom',
    'Rutland': 'United Kingdom',
    'Cheshire': 'United Kingdom',
    'Colchester': 'United Kingdom',
    'Southampton': 'United Kingdom',
    'Norfolk': 'United Kingdom',
    'Abingdon': 'United Kingdom',
    'Burgess Hill': 'United Kingdom',
    'Stoke Newington - London': 'United Kingdom',
    'Wageningen': 'Netherlands',
    'West Sussex': 'United Kingdom',
    'Ashford Kent': 'United Kingdom',
    'Roquetes': 'Spain',
    'Florence': 'Italy',
    'La Seu d’Urgell': 'Spain',
    'Manresa': 'Spain',
    'Amposta': 'Spain',
    'Palencia': 'Spain',
    'Edinburgh': 'United Kingdom',
    'Royal Wootton Bassett': 'United Kingdom',
    'Antwerp': 'Belgium',
    'Sheffield': 'United Kingdom',
    'Devon UK': 'United Kingdom',
    'Braunschweig (Germany)': 'Germany',
    'Cumbria': 'United Kingdom',
    'Harrogate': 'United Kingdom',
    'Nomad': 'Unknown',
    'Scottish Highlands': 'United Kingdom',
    'Hassloch': 'Germany',
    'Mittelgebirge Classique 2023!': 'Germany',
    'Hemmingen': 'Germany',
    'Dresden': 'Germany',
    'Le Mans / France': 'France',
    'Wrocław': 'Poland',
    'Poznań / Poland': 'Poland',
    'Chepstow': 'United Kingdom',
    'eydon': 'Unknown',
    'Folkestone': 'United Kingdom',
    'Exeter': 'United Kingdom',
    'Frome': 'United Kingdom',
    'Palmela': 'Portugal',
    'Benedita': 'Portugal',
    'Murrhardt - Germany': 'Germany',
    'Bergamo': 'Italy',
    'Ireland': 'Ireland',
    'Kent': 'United Kingdom',
    'Kidderminster': 'United Kingdom',
    'Nottingham': 'United Kingdom',
    'Bath': 'United Kingdom',
    'Caerleon': 'United Kingdom',
    'Somerset UK': 'United Kingdom',
    'Celje - Slovenia': 'Slovenia',
    'Siegen': 'Germany',
    'Leipzig / Germany': 'Germany',
    'leipzig / Germany': 'Germany',
    'San Pietro di Feletto': 'Italy',
    'Forli': 'Italy',
    'Cesiomaggiore (BL) Italy': 'Italy',
    'SEGUSINO TREVISO ITALY': 'Italy',
    'Solagna': 'Italy',
    'Nantes (FR)': 'France',
    'Konstanz': 'Germany',
    'Bilbao (SPAIN': 'Spain',
    'Garmisch Partykirchen': 'Germany',
    'Bern': 'Switzerland',
    'Zürich': 'Switzerland',
    'Basel': 'Switzerland',
    'Hachenburg': 'Germany',
    'Lokeren / Belgium': 'Belgium',
    'Marseille bébé': 'France',
    'Lille': 'France',
    'Antwerp - Belgium': 'Belgium',
    'CALDERS': 'Unknown',
    'Cracow (Poland)': 'Poland',
    'Germany (Munich)': 'Germany',
    'Letterkenny': 'Ireland',
    'Marseille FRANCE': 'France',
    'Northern Ireland': 'United Kingdom',
    'Wexford Ireland': 'Ireland',
    'Coín Malaga España': 'Spain',
    'Hamburg': 'Germany',
    'Heidelberg Germany': 'Germany',
    'Peak District': 'United Kingdom',
    'Montreal': 'Canada',
    'Göttingen Germany': 'Germany',
    'Orzola': 'Spain',
    'Lausanne (Switzerland)': 'Switzerland',
    'Dubai': 'United Arab Emirates',
    'Munich (Germany) and Girona (Spain)': 'Germany',
    'UAE': 'United Arab Emirates',
    'Canadian living in Namibia': 'Namibia',
    'Rwanda': 'Rwanda',
    'Chile' : 'Chile',
    'Mexico': 'Mexico',
    'A Canadian based in Dubai.': 'United Arab Emirates', 
    "Scl": "Country Not Found",
    "Brasil": "Brazil",
    "Viña Del Mar. Chile": "Chile",
    "Santiago de Chile": "Chile",
    "Bariloche Argentina": "Argentina",
    "Guatemala": "Guatemala",
    "CDMX/Argentina": "Argentina",
    "Santiago": "Chile",
    "Santiago. Chile": "Chile",
    "Temuco": "Chile",
    "Brazil": "Brazil",
    "Liverpool": "United Kingdom",
    "Capbreton France": "France",
    "Worldwide": "Country Not Found",
    "Vaugneray France": "France",
    "68": "Country Not Found",
    "In a hut (Refuge du Ruhle)": "Country Not Found",
    "Dutch living in France Alps (Puy Saint Vincent)": "France",
    "Leeds": "United Kingdom",
    "People's Republic of Kernow (Cornwall)": "United Kingdom",
    "LDN": "United Kingdom",
    "Forest of Dean": "United Kingdom",
    "Indonesia": "Indonesia",
    "Bandung": "Indonesia",
    "Bogor": "Indonesia",
    "Jakarta": "Indonesia",
    "Jakarat": "Indonesia",
    "Vilanova i la Geltrú": "Spain",
    "Coventry": "United Kingdom",
    "Chapel En Le Frith": "United Kingdom",
    "Lewes": "United Kingdom",
    "Denmark": "Denmark",
    "German/ based in Switzerland": "Switzerland",
    "Dartmouth. Nova Scotia. Canada": "Canada",
    "Leipzig/GER": "Germany",
    "in train": "Country Not Found",
    "Tewkesbury": "United Kingdom",
    "Leighton Buzzard": "United Kingdom",
    "Carlisle": "United Kingdom",
    "Swindon": "United Kingdom",
    "Wiltshire UK": "United Kingdom",
    "Perthshire": "United Kingdom",
    "FOCC BRISTOL": "United Kingdom",
    "Usk": "United Kingdom",
    "Warrington": "United Kingdom",
    "Seva": "Country Not Found",
    "Singapore": "Singapore",
    "España": "Spain",
    "Ins": "Country Not Found",
    "Bonn": "Germany",
    "Zürich (Switzerland)": "Switzerland",
    "Steinhuserberg / Switzerland": "Switzerland",
    "Torino": "Italy",
    "Bologna Italy": "Italy",
    "Enskede": "Country Not Found",
    "Taiwan": "Taiwan",
    "Inverness": "United Kingdom",
    "Disley": "United Kingdom",
    "Durham": "United Kingdom",
    "Aviemore": "United Kingdom",
    "German/ based in Basel (CH)": "Switzerland",
    "Amiens from france": "France",
    "Getxo": "Spain",
    "Maspujols": "Spain",
    "Manlleu": "Spain",
    "Reus (Catalunya)": "Spain",
    "Torelló": "Spain",
    "Zaragoza (Spain)": "Spain",
    "Lugo": "Spain",
    "Dresden; Germany": "Germany",
    "Warsaw": "Poland",
    "Dresden - Germany": "Germany",
    "Kraków": "Poland",
    "Krakow": "Poland",
    "Gdańsk": "Poland",
    "Budapest": "Hungary",
    "Conegliano Veneto Italy": "Italy",
    "Salzburg": "Austria",
    "Mallorca Spain": "Spain",
    "Würzburg Germany": "Germany",
    "Pécs": "Hungary",
    "Rouen (France)": "France",
    "Esslingen (Germany)": "Germany",
    "Warnsveld": "Netherlands",
    "Sint-Michielsgestel": "Netherlands",
    "Cambridge": "United Kingdom",
    "Vreeswijk": "Country Not Found",
    "Den Haag": "Netherlands",
    "Prague": "Czech Republic",
    "Gleisdorf/Austria": "Austria",
    "Helmond": "Netherlands",
    "Germany Oldenburg": "Germany",
    "Amersfoort": "Netherlands",
    "Sneek": "Netherlands",
    "CzechRepublic": "Czech Republic",
    "Scotland": "United Kingdom",
    "Koblenz Germany": "Germany",
    "Lithuanian living in Norway": "Norway",
    "Nelson": "New Zealand",
    "Christchurch": "New Zealand",
    "Rotorua NZ": "New Zealand",
    "Timaru": "New Zealand",
    "Kapiti Coast": "New Zealand",
    "Auckland": "New Zealand",
    "Taupo": "New Zealand",
    "Wellington": "New Zealand",
    "Drury": "New Zealand",
    "Rotorua": "New Zealand",
    "Hamilton": "New Zealand",
    "Kingston": "Country Not Found",
    "Wanaka": "New Zealand",
    }

# %%
df_country = pd.DataFrame.from_dict(country_mapping, orient='index')
df_country.reset_index(inplace=True)
df_country.columns = ['location', 'country']
df_country.head(5)
# Out:
#                   location         country
# 0  Oxfordshire/Uni of Bath  United Kingdom
# 1                  Glasgow  United Kingdom
# 2                    Italy           Italy
# 3                   Norway          Norway
# 4                Istraland           Italy

# %%
# remove country column from problem_country dataframe

problem_country = problem_country.drop(columns=['country'])

# merge problem_country with df_country by location

problem_country = problem_country.merge(df_country, on='location', how='left')
problem_country.head(5)
# Out:
#                           name   age                 location  \
# 0                Bryce Jersing  23.0  Oxfordshire/Uni of Bath
# 1               Alex Fthenakis  37.0                  Glasgow
# 2              federico bassis  32.0                    Italy
# 3             Henning Roalkvam  48.0                   Norway
# 4  Andrea / Bike like a couple  39.0                Istraland
#
#                                                 bike  \
# 0  Riding to raise money for Movember on my trust...
# 1  Albannach Torragar with Rodeo Spork Forks, a m...
# 2                   Basso Palta Team Enough Cycling.
# 3  Basso Palta. The bike is equipped with a SRAM ...
# 4              OPEN U.P Telaio, Campagnolo Ekar 13v.
#
#                                     key items of kit             race  \
# 0  Tailfin AeroPack: Alpkit/Decathlon-based sleep...         GBDURO23
# 1  Cyclite aero bar bag mostly for jackets, glove...         GBDURO23
# 2                                  Miss Grape packs.  Istra Land 2023
# 3           Lights are Sinewave Beacon dynamo light.  Istra Land 2023
# 4  Ruote Hed Emporia, Sella Fizik Terra Argo, Por...  Istra Land 2023
#
#                                                 link         country
# 0    https://dotwatcher.cc/feature/bikes-of-gbduro23  United Kingdom
# 1    https://dotwatcher.cc/feature/bikes-of-gbduro23  United Kingdom
# 2  https://dotwatcher.cc/feature/bikes-of-istra-l...           Italy
# 3  https://dotwatcher.cc/feature/bikes-of-istra-l...          Norway
# 4  https://dotwatcher.cc/feature/bikes-of-istra-l...           Italy

# %%
# filter rows where location is 'Chile' is problem_country dataframe

# %%
# reorder columns in problem_country dataframe

problem_country = problem_country[['name', 'age', 'country', 'location', 'bike', 'key items of kit', 'race', 'link']]

# %%
# select rows with no missing values in country column

dotwatch_not_null = dotwatch[dotwatch['country'].notnull()]

# %%
# concatenate problem_country and dotwatch_not_null dataframes

dotwatch_clean = pd.concat([dotwatch_not_null, problem_country], axis=0)

# %%
missing_countries = dotwatch_clean[dotwatch_clean['country'].isnull()]

# %%
missing_countries.location.unique()
# Out:
# array([nan], dtype=object)

# %%
dotwatch_clean['bike'].unique()[0:10]
# Out:
# array(['I will be riding the GBDURO23 with my beloved Kona Sutra LTD. Even though the steel frame is not the lightest, it has demonstrated its robustness in many other journeys, and my familiarity with the frame should hopefully allow me to perform some repairs on the way if necessary. A 34T chainring in the front and a 10-42T cassette should hopefully do the trick to get me through the hilly parts of the UK. For tires I went with 45mm Schwalbe G-One R.',
#        'Mason Bokeh mk.1 with Hunt 650b dynamo wheel set.',
#        'Fairlight Secan, GRX X2, Hunt Dynamo Wheelset with Panaracer Gravelking SK+ tyres.',
#        'I’ll be riding the GBDuro23 on my Salsa Cutthroat 2019 because it’s the only Bikepacking bike I own, all built up second hand over the past 4 years. My drivetrain is 12sp Eagle XX1 with Sram Force controls paired with RatioTechnology.com 12sp conversion. The wheels are Enve with DT Swiss rear and SON28 front hubs built by DCRWheels.com and with Teravail Spawood 2.2 tyres as much for comfort as for speed. My seatpost is a Canyon VCLS 2.0 with flex for comfort too.  My bags are a mixture of Spoked-UK, Wildcat.cc and Alpkit but the majority made bespoke by WldSkyGear.co.uk from dynema-DCF for weight saving.  I run the dynamo hub through a Sinewave Beacon light that charges stuff and runs my eTrex GPS along with an Exposure Joystick for when it’s dark but too slow to produce much light.  Much of my bike setup is held together by cable ties and sticky tape!',
#        "Kinesis GTD v2 (aka 'Goat HeaD'), mostly Shimano Ultegra throughout and Thomson seat post and stem. Retro Easton bars (with Profile Design aero bars) and Hunt Superdura dynamo wheelset.",
#        "Surly Midnight Special and a brother's fork using a 38t chainring and 42-11t cassette. A mix of SRAM Force and GX groupset. Profile design aerobars for more positions, a Redshift stem for comfort and DT swiss wheels with 350 hubs.",
#        'Sonder Broken Road, SID Ultimate SL fork, Sonder Alpha XC 29 wheelset, Schwalbe G-One 2.25 tyres, Cane Creek Thudbuster ST seaport, Brooks B17 saddle, SRAM GX AXS, Aero Spider rack system, Alpkit bags & luggage.',
#        'Salsa Warbird with GRX Di2 groupset, Roval Terra CL wheels, Vittoria Mezcal 44mm tires, Specialized Power Comp saddle, Redshift Shockstop stem and Ritchey Butano 42cm handlebar. This is my full "treat yourself" bike.',
#        'Bike: Charge Plug 5 Ti (2016) - this bike has done more than 70,000km!\nGroupset: Sram Rival 1x, 38T front chainring and 11-46 at the rear. Wheels: Hunt Superdura Disc with Son Dynamo. Tyres: Pirelli Cinturato M. Not the best tyre clearance, so running 45mm front, 40mm rear. Cockpit: Redshift ShockStop stem, Deda TT bars.',
#        'Sonder Camino Al with a Calibri fork. 2×11 drivetrain using a mix of GRX and 105; 11-42 cassette and a 50/34 crankset.'],
#       dtype=object)

# %%
skim(dotwatch_clean)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 2111   │ │ string      │ 7     │                                                          │
# │ │ Number of columns │ 8      │ │ float64     │ 1     │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━┳━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┓  │
# │ ┃ column_name        ┃ NA   ┃ NA %    ┃ mean    ┃ sd   ┃ p0   ┃ p25    ┃ p50    ┃ p75   ┃ p100    ┃ hist     ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━╇━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━╇━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━┩  │
# │ │ age                │    7 │    0.33 │      40 │   10 │    4 │     32 │     38 │    47 │      73 │   ▁▇▅▃   │  │
# │ └────────────────────┴──────┴─────────┴─────────┴──────┴──────┴────────┴────────┴───────┴─────────┴──────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name                      ┃ NA     ┃ NA %      ┃ words per row              ┃ total words           ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ name                             │      0 │         0 │                        2.1 │                  4396 │  │
# │ │ country                          │      2 │      0.09 │                        1.2 │                  2571 │  │
# │ │ location                         │      2 │      0.09 │                          2 │                  4124 │  │
# │ │ bike                             │      0 │         0 │                         23 │                 48064 │  │
# │ │ key items of kit                 │      4 │      0.19 │                         31 │                 65714 │  │
# │ │ race                             │      0 │         0 │                        3.8 │                  7952 │  │
# │ │ link                             │      0 │         0 │                          1 │                  2111 │  │
# │ └──────────────────────────────────┴────────┴───────────┴────────────────────────────┴───────────────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %%
# G

dotwatch_clean.country.unique()
# Out:
# array(['Germany', 'UK', 'Yorkshire Dales', 'Scotland', 'Belgium', 'Wales',
#        'uk', 'Cornwall', 'France', 'Greece', 'England', 'Austria',
#        'Italy', 'Poland', 'Switzerland', 'Czech republic', 'Croatia',
#        'Slovenia', 'Netherlands', 'Pyrénées Atlantiques', 'Australia',
#        'Sweden', 'Antwerp', 'FRANCE', 'Bergisches Land', 'Colorado',
#        'The Netherlands', 'Canada', 'Somerset', 'Essex', 'Deutschland',
#        'Norway', 'USA', 'United Kingdom', 'South Wales', 'Spain',
#        'Canarias', 'NL', 'Nederland', 'Netherland', 'Bad Hersfeld',
#        'the Netherlands', 'Miraflores de la Sierra', 'Arkansas',
#        'North York Moors', 'Gywnedd', 'Ontario', 'NY', 'Québec', 'VT',
#        'Qc', 'ON', 'QC', 'Quebec', 'Portugal', 'Euskal Herria',
#        'Basque country', 'Denmark', 'España', 'Barcelona', 'UK.',
#        'Colombia', 'Chile', 'Scotland.', 'West Sussex. UK', 'Dorset',
#        'France.', 'Finland', 'Rutland', 'North Wales', 'Gelderland',
#        'Wales.', 'Sussex', 'Channel Islands', 'East Sussex', 'Czechia',
#        'WA (USA)', 'CA', 'Kaltland', 'Latvia', 'Norway.', 'Utah',
#        'Hannover', 'Lithuania', 'Hamburg', 'Oregon USA', 'China', 'spain',
#        'Hampshire', 'Ireland', 'Berks', 'GR', 'Cumbria',
#        'Denmark. From the UK.', 'South Africa', 'Cologne', 'RLP', 'Kerry',
#        'Liberties', 'NI', 'South Shropshire', 'Shropshire', 'Cheshire',
#        'UK (originally from Novocherkassk', 'Bosnia and Herzegovina',
#        'Bulgaria', 'South Tyrol', 'United Arab Emirates', 'Como',
#        'Estonia', 'New Zealand', 'originally from Arnstorf (Germany)',
#        'California', 'Northants', 'Derbyshire', 'Isle of Wight',
#        'West Sussex', 'Devon', 'North Yorkshire', 'Kent', 'kent',
#        'Lancashire', 'Penrith', 'UT', 'Highlands', 'Co. Meath',
#        'Greater Manchester', 'Fife', 'Germnay', 'Schweiz', 'Romania',
#        'PL', 'Polska', 'Aveiro Portugal', 'Portugal.', 'Washington',
#        'German7', 'Tirol', 'Surrey', 'Catalunya', 'Lincolnshire',
#        'Catalonia', 'Suisse', 'Ticino', 'france', 'Savoie', 'Auatria',
#        'North Wales.', 'Ukraine', 'Región de Los Lagos', 'Brazil',
#        'Brasil', 'Mexico', 'V Región de Valparaíso', 'RS', 'Buenos Aires',
#        'Paraná/Brasil', 'Chile (Spanish nationality)',
#        'Región de la Araucanía', 'chile', 'CHILE', 'Argentina', 'Utrecht',
#        'Luxembourg', 'Pyrénées Orientales', 'FR', 'Charente',
#        'Le Nooooorrrd de la France', 'Swizterland', 'Northumberland',
#        'Swansea', 'Yorkshire', 'Indonesia', 'Malaysia',
#        'Tangerang Selatan', 'Uk', 'Niedersachsen', 'Lower Saxony',
#        'Slovakia', 'Argyll and Bute', 'Northern Ireland', 'QC Canada',
#        'Aberdeenshire', 'England.', 'MO', 'Cornwall & La Ciotat',
#        'Berkshire', 'Belgium.', "Principat d'Andorra", 'Spain.',
#        'Basque Country.', 'Colombia.', 'Sonnenbühl', 'Perugia', 'Hungary',
#        'Tenerife', 'Catalunya.', 'Republic of Moldova', 'AT', 'Austria.',
#        'Nijkerk.', 'Noord Brabant', 'Czech Republic', 'Kenya',
#        'France / Rwanda', 'Rwanda', 'NZ', 'Golden Bay', 'Wellington',
#        'Turkey', 'Saudi Arabia', 'United States', nan, 'Unknown',
#        'Namibia', 'Country Not Found', 'Guatemala', 'Singapore', 'Taiwan'],
#       dtype=object)

# %%
bikepacking.columns
# Out:
# Index(['name', 'age', 'country', 'location', 'bike', 'bags', 'gear', 'route',
#        'race', 'link'],
#       dtype='object')

# %%
dotwatch_clean.columns
# Out:
# Index(['name', 'age', 'country', 'location', 'bike', 'key items of kit',
#        'race', 'link'],
#       dtype='object')

# %%
dotwatch_clean['source'] = 'dotwatcher.cc'
dotwatch_clean['bags'] = np.nan
dotwatch_clean['gear'] = dotwatch_clean['key items of kit']

# %%
bikepacking['source'] = 'bikepacking.com'

# %%
bikepacking_final =  bikepacking[['name', 'age', 'country', 'location', 'bike', 'bags', 'gear', 'race', 'link', 'source']]

# %%
# re order columns in dotwatch_clean according to bikepacking_final columns

dotwatch_clean = dotwatch_clean[bikepacking_final.columns]
dotwatch_clean
# Out:
#                    name   age            country                   location  \
# 0        Nils Opgenorth  27.0            Germany         Stuttgart, Germany
# 1              Tom Hall  42.0                 UK                 Sussex, UK
# 2       Jordan Matthews  30.0                 UK             Sunderland, UK
# 3         Chris Ellison  60.0    Yorkshire Dales  Austwick, Yorkshire Dales
# 4            Tim Taylor  48.0                 UK           Warwickshire, UK
# ..                  ...   ...                ...                        ...
# 784        Cati Pearson  31.0        New Zealand                    Rotorua
# 785         Mike Martin  37.0        New Zealand                   Hamilton
# 786         Andie Lowry  38.0  Country Not Found                   Kingston
# 787        Scott Ardern  52.0        New Zealand                     Nelson
# 788  Georgie Rutherford  38.0        New Zealand                     Wanaka
#
#                                                   bike  bags  \
# 0    I will be riding the GBDURO23 with my beloved ...   NaN
# 1    Mason Bokeh mk.1 with Hunt 650b dynamo wheel set.   NaN
# 2    Fairlight Secan, GRX X2, Hunt Dynamo Wheelset ...   NaN
# 3    I’ll be riding the GBDuro23 on my Salsa Cutthr...   NaN
# 4    Kinesis GTD v2 (aka 'Goat HeaD'), mostly Shima...   NaN
# ..                                                 ...   ...
# 784  2021 Devinci Kobain kept running smooth and fi...   NaN
# 785  GT Pantera with Hope Fortus wheels and 120mm t...   NaN
# 786                                    Kona HEI HEI DL   NaN
# 787                                Specialized Epic HT   NaN
# 788  2018 Scott Genius 700 tuned, 12 speed shimano ...   NaN
#
#                                                   gear  \
# 0    I spent some time organising the front of the ...
# 1    Apidura rig, 7l seat pack, frame pack, long to...
# 2    Alpkit, Ortlieb and Straight Cut bags.\nTent, ...
# 3    Much of my cold weather down and sleep gear is...
# 4    Re-strap and Apidura bags. Exposure lights. Sl...
# ..                                                 ...
# 784  All clothing from the legends at Ground Effect...
# 785  Ground effect bibs and a Rapha top (cheers to ...
# 786                                            Bum bag
# 787  Revelate bags, SON Dynamo and K-Lite lights Fe...
# 788  Apidura front handle bar roll and seat pack, a...
#
#                         race  \
# 0                   GBDURO23
# 1                   GBDURO23
# 2                   GBDURO23
# 3                   GBDURO23
# 4                   GBDURO23
# ..                       ...
# 784  Tour Te Waipounamu 2022
# 785  Tour Te Waipounamu 2022
# 786  Tour Te Waipounamu 2022
# 787  Tour Te Waipounamu 2022
# 788  Tour Te Waipounamu 2022
#
#                                                   link         source
# 0      https://dotwatcher.cc/feature/bikes-of-gbduro23  dotwatcher.cc
# 1      https://dotwatcher.cc/feature/bikes-of-gbduro23  dotwatcher.cc
# 2      https://dotwatcher.cc/feature/bikes-of-gbduro23  dotwatcher.cc
# 3      https://dotwatcher.cc/feature/bikes-of-gbduro23  dotwatcher.cc
# 4      https://dotwatcher.cc/feature/bikes-of-gbduro23  dotwatcher.cc
# ..                                                 ...            ...
# 784  https://dotwatcher.cc/feature/bikes-of-tour-te...  dotwatcher.cc
# 785  https://dotwatcher.cc/feature/bikes-of-tour-te...  dotwatcher.cc
# 786  https://dotwatcher.cc/feature/bikes-of-tour-te...  dotwatcher.cc
# 787  https://dotwatcher.cc/feature/bikes-of-tour-te...  dotwatcher.cc
# 788  https://dotwatcher.cc/feature/bikes-of-tour-te...  dotwatcher.cc
#
# [2111 rows x 10 columns]

# %%
# concatenate bikepacking_final and dotwatch_clean dataframes

df_final = pd.concat([bikepacking_final, dotwatch_clean], axis=0)
df_final
# Out:
#                    name   age            country                    location  \
# 0         Miron Golfman  30.0                USA      Anchorage Alaska (USA)
# 1          Matt Annabel  48.0                USA  Carbondale, Colorado (USA)
# 2         Ryan Bartelme  36.0                USA       Tucson, Arizona (USA)
# 3       Thomas Duehrsen  52.0        Switzerland          Thun (Switzerland)
# 4         Elliot DuMont  35.0                USA       Tucson, Arizona (USA)
# ..                  ...   ...                ...                         ...
# 784        Cati Pearson  31.0        New Zealand                     Rotorua
# 785         Mike Martin  37.0        New Zealand                    Hamilton
# 786         Andie Lowry  38.0  Country Not Found                    Kingston
# 787        Scott Ardern  52.0        New Zealand                      Nelson
# 788  Georgie Rutherford  38.0        New Zealand                      Wanaka
#
#                                                   bike  \
# 0    I’m riding a Santa Cruz Blur, with SRAM XO1 dr...
# 1    I’ll be piloting “Badger,” my singlespeed Why ...
# 2    I’ll be riding AZTR300 on a 2021 Yeti SB130 CL...
# 3    2022 ToutTerrain Outback 27.5 steel with Pinio...
# 4    Soma Juice, Shimano 1×12 (30T chainring), home...
# ..                                                 ...
# 784  2021 Devinci Kobain kept running smooth and fi...
# 785  GT Pantera with Hope Fortus wheels and 120mm t...
# 786                                    Kona HEI HEI DL
# 787                                Specialized Epic HT
# 788  2018 Scott Genius 700 tuned, 12 speed shimano ...
#
#                                                   bags  \
# 0    DTF dreams custom handlebar bag, Woolf Tooth b...
# 1    A much loved Rogue Panda Canelo bar-harness le...
# 2    If Miles issues an award for bike bag hacks, I...
# 3    Made myself a HF welded framebag from PVC coat...
# 4    Bags by Revelate, Nuclear Sunrise, Diday, and ...
# ..                                                 ...
# 784                                                NaN
# 785                                                NaN
# 786                                                NaN
# 787                                                NaN
# 788                                                NaN
#
#                                                   gear  \
# 0    KLite Ultra Racing Lighting System w/ Bar swit...
# 1    The dynamo has one job: to juice my Garmin 104...
# 2    I brought a small stove for hot coffee and oat...
# 3    My Pedalcell broke shortly before the trip and...
# 4    My trusty Brooks B17 saddle and a Mystery Ranc...
# ..                                                 ...
# 784  All clothing from the legends at Ground Effect...
# 785  Ground effect bibs and a Rapha top (cheers to ...
# 786                                            Bum bag
# 787  Revelate bags, SON Dynamo and K-Lite lights Fe...
# 788  Apidura front handle bar roll and seat pack, a...
#
#                                 race  \
# 0     2023 Arizona Trail Race (AZTR)
# 1     2023 Arizona Trail Race (AZTR)
# 2     2023 Arizona Trail Race (AZTR)
# 3     2023 Arizona Trail Race (AZTR)
# 4     2023 Arizona Trail Race (AZTR)
# ..                               ...
# 784          Tour Te Waipounamu 2022
# 785          Tour Te Waipounamu 2022
# 786          Tour Te Waipounamu 2022
# 787          Tour Te Waipounamu 2022
# 788          Tour Te Waipounamu 2022
#
#                                                   link           source
# 0    https://bikepacking.com/bikes/2023-arizona-tra...  bikepacking.com
# 1    https://bikepacking.com/bikes/2023-arizona-tra...  bikepacking.com
# 2    https://bikepacking.com/bikes/2023-arizona-tra...  bikepacking.com
# 3    https://bikepacking.com/bikes/2023-arizona-tra...  bikepacking.com
# 4    https://bikepacking.com/bikes/2023-arizona-tra...  bikepacking.com
# ..                                                 ...              ...
# 784  https://dotwatcher.cc/feature/bikes-of-tour-te...    dotwatcher.cc
# 785  https://dotwatcher.cc/feature/bikes-of-tour-te...    dotwatcher.cc
# 786  https://dotwatcher.cc/feature/bikes-of-tour-te...    dotwatcher.cc
# 787  https://dotwatcher.cc/feature/bikes-of-tour-te...    dotwatcher.cc
# 788  https://dotwatcher.cc/feature/bikes-of-tour-te...    dotwatcher.cc
#
# [5074 rows x 10 columns]

# %%
# extract number from link column in df_final dataframe

df_final['year'] = df_final['link'].str.extract('(\d+)')

# %%
# create a function to extract the year in the link column

def extract_year(df):
    # Assuming 'link' is the column containing the information
    df['year'] = df['link'].str.extract(r'(2018|2019|2020|2021|2022|2023)').astype(float)
    
    return df

# %%
df_final = extract_year(df_final)

# %%
location_country_dict = {
    'USA': 'United States',
    'Switzerland': 'Switzerland',
    'Canada': 'Canada',
    'Ecuador': 'Ecuador',
    'No info': 'No information',
    'Spain': 'Spain',
    'The Netherlands': 'Netherlands',
    'Germany': 'Germany',
    'Italy': 'Italy',
    'Finland': 'Finland',
    'Ireland': 'Ireland',
    'Belgium': 'Belgium',
    'Portugal': 'Portugal',
    'Philippines': 'Philippines',
    'Scotland': 'Scotland',
    'United Kingdom': 'United Kingdom',
    'Denmark': 'Denmark',
    'South Africa': 'South Africa',
    'France': 'France',
    'Poland': 'Poland',
    'Austria': 'Austria',
    'Sweden': 'Sweden',
    'Norway': 'Norway',
    'Australia': 'Australia',
    'England': 'England',
    'Kyrgyzstan': 'Kyrgyzstan',
    'Kazakhstan': 'Kazakhstan',
    'Netherlands': 'Netherlands',
    'Czech Republic': 'Czech Republic',
    'Hungary': 'Hungary',
    'China': 'China',
    'New Zealand': 'New Zealand',
    'Swtizerland': 'Switzerland',  # Corrected typo
    'Russia': 'Russia',
    'Indonesia': 'Indonesia',
    'Latvia': 'Latvia',
    'UK': 'United Kingdom',
    'Georgia': 'Georgia',
    'Armenia': 'Armenia',
    'Belarus': 'Belarus',
    'Estonia': 'Estonia',
    'Wales': 'Wales',
    'FRANCE': 'France',
    'Romania': 'Romania',
    'South Korea': 'South Korea',
    'Greece': 'Greece',
    'on Gadigal land': 'Australia',
    'Morocco': 'Morocco',
    'Israel': 'Israel',
    'Madagascar': 'Madagascar',
    'North Ireland': 'Northern Ireland',
    'Canary Islands': 'Canary Islands',
    'South of France': 'France',
    'Oslo': 'Norway',
    'Basque Country': 'Spain',
    'United kingdom': 'United Kingdom',
    'Granada': 'Spain',
    'Caracas/Venezuela': 'Venezuela',
    'Northern Ireland': 'Northern Ireland',
    'Venezuela': 'Venezuela',
    'Turkey': 'Turkey',
    'Slovakia': 'Slovakia',
    'NZ': 'New Zealand',
    'Taiwan': 'Taiwan',
    'AUS': 'Australia',
    'Atlanta, Georgia, USA': 'United States',
    'Born and raised in Papua New Guinea': 'Papua New Guinea',
    'Catalonia': 'Spain',
    'St. Pete Beach': 'United States',
    'Lithuania': 'Lithuania',
    'Colorado': 'United States',
    'Lativa': 'Latvia',
    'Amah Mutsun': 'Unknown',  # No specific country mentioned
    'ITALY': 'Italy',
    'GER': 'Germany',
    '390ft': 'Unknown',  # No specific country mentioned
    'Aboriginal community': 'Unknown',  # No specific country mentioned
    'CA': 'Canada',
    'St Pete Beach': 'United States',
    'CANADA': 'Canada',
    'currently residing in Alexandria, VA': 'United States',
    'but proudly Dutch': 'Netherlands',
    'CZE': 'Czech Republic',
    'Yorkshire Dales': 'United Kingdom',
    'uk': 'United Kingdom',
    'Cornwall': 'United Kingdom',
    'Czech republic': 'Czech Republic',
    'Croatia': 'Croatia',
    'Slovenia': 'Slovenia',
    'Pyrénées Atlantiques': 'France',
    'Antwerp': 'Belgium',
    'Bergisches Land': 'Germany',
    'Somerset': 'United Kingdom',
    'Essex': 'United Kingdom',
    'Deutschland': 'Germany',
    'South Wales': 'United Kingdom',
    'Canarias': 'Spain',
    'NL': 'Netherlands',
    'Nederland': 'Netherlands',
    'Netherland': 'Netherlands',
    'Bad Hersfeld': 'Germany',
    'the Netherlands': 'Netherlands',
    'Miraflores de la Sierra': 'Spain',
    'Arkansas': 'United States',
    'North York Moors': 'United Kingdom',
    'Gywnedd': 'United Kingdom',
    'Ontario': 'Canada',
    'NY': 'United States',
    'Québec': 'Canada',
    'VT': 'United States',
    'Qc': 'Canada',
    'ON': 'Canada',
    'QC': 'Canada',
    'Quebec': 'Canada',
    'Euskal Herria': 'Spain',
    'Basque country': 'Spain',
    'España': 'Spain',
    'Barcelona': 'Spain',
    'UK.': 'United Kingdom',
    'Colombia': 'Colombia',
    'Chile': 'Chile',
    'Scotland.': 'Scotland',
    'West Sussex. UK': 'United Kingdom',
    'Dorset': 'United Kingdom',
    'France.': 'France',
    'Rutland': 'United Kingdom',
    'North Wales': 'United Kingdom',
    'Gelderland': 'Netherlands',
    'Wales.': 'United Kingdom',
    'Sussex': 'United Kingdom',
    'Channel Islands': 'United Kingdom',
    'East Sussex': 'United Kingdom',
    'Czechia': 'Czech Republic',
    'WA (USA)': 'United States',
    'Kaltland': 'Unknown',  # No specific country mentioned
    'Norway.': 'Norway',
    'Utah': 'United States',
    'Hannover': 'Germany',
    'Hamburg': 'Germany',
    'Oregon USA': 'United States',
    'spain': 'Spain',
    'Hampshire': 'United Kingdom',
    'Berks': 'United Kingdom',
    'GR': 'Greece',
    'Cumbria': 'United Kingdom',
    'Denmark. From the UK.': 'United Kingdom',
    'Cologne': 'Germany',
    'RLP': 'Germany',
    'Kerry': 'Ireland',
    'Liberties': 'Ireland',
    'NI': 'Northern Ireland',
    'South Shropshire': 'United Kingdom',
    'Shropshire': 'United Kingdom',
    'Cheshire': 'United Kingdom',
    'UK (originally from Novocherkassk': 'United Kingdom',
    'Bosnia and Herzegovina': 'Bosnia and Herzegovina',
    'Bulgaria': 'Bulgaria',
    'South Tyrol': 'Italy',
    'United Arab Emirates': 'United Arab Emirates',
    'Como': 'Italy',
    'originally from Arnstorf (Germany)': 'Germany',
    'California': 'United States',
    'Northants': 'United Kingdom',
    'Derbyshire': 'United Kingdom',
    'Isle of Wight': 'United Kingdom',
    'West Sussex': 'United Kingdom',
    'Devon': 'United Kingdom',
    'North Yorkshire': 'United Kingdom',
    'Kent': 'United Kingdom',
    'kent': 'United Kingdom',
    'Lancashire': 'United Kingdom',
    'Penrith': 'United Kingdom',
    'UT': 'United States',
    'Highlands': 'United Kingdom',
    'Co. Meath': 'Ireland',
    'Greater Manchester': 'United Kingdom',
    'Fife': 'United Kingdom',
    'Germnay': 'Germany',  # Corrected typo
    'Schweiz': 'Switzerland',
    'PL': 'Poland',
    'Polska': 'Poland',
    'Aveiro Portugal': 'Portugal',
    'Portugal.': 'Portugal',
    'Washington': 'United States',
    'German7': 'Germany',
    'Tirol': 'Austria',
    'Surrey': 'United Kingdom',
    'Catalunya': 'Spain',
    'Lincolnshire': 'United Kingdom',
    'Suisse': 'Switzerland',
    'Ticino': 'Switzerland',
    'france': 'France',  # Corrected lowercase entry
    'Savoie': 'France',
    'Auatria': 'Austria',  # Corrected typo
    'North Wales.': 'United Kingdom',
    'Ukraine': 'Ukraine',
    'Región de Los Lagos': 'Chile',
    'Brazil': 'Brazil',
    'Brasil': 'Brazil',
    'Mexico': 'Mexico',
    'V Región de Valparaíso': 'Chile',
    'RS': 'Brazil',
    'Buenos Aires': 'Argentina',
    'Paraná/Brasil': 'Brazil',
    'Chile (Spanish nationality)': 'Chile',
    'Región de la Araucanía': 'Chile',
    'chile': 'Chile',
    'CHILE': 'Chile',
    'Argentina': 'Argentina',
    'Utrecht': 'Netherlands',
    'Luxembourg': 'Luxembourg',
    'Pyrénées Orientales': 'France',
    'FR': 'France',
    'Charente': 'France',
    'Le Nooooorrrd de la France': 'France',
    'Swizterland': 'Switzerland',  # Corrected typo
    'Northumberland': 'United Kingdom',
    'Swansea': 'United Kingdom',
    'Yorkshire': 'United Kingdom',
    'Malaysia': 'Malaysia',
    'Tangerang Selatan': 'Indonesia',
    'Uk': 'United Kingdom',
    'Niedersachsen': 'Germany',
    'Lower Saxony': 'Germany',
    'Argyll and Bute': 'United Kingdom',
    'QC Canada': 'Canada',
    'Aberdeenshire': 'United Kingdom',
    'England.': 'United Kingdom',
    'MO': 'United States',
    'Cornwall & La Ciotat': 'United Kingdom',  # Combined two locations
    'Berkshire': 'United Kingdom',
    'Belgium.': 'Belgium',
    "Principat d'Andorra": 'Andorra',
    'Spain.': 'Spain',
    'Basque Country.': 'Spain',
    'Colombia.': 'Colombia',
    'Sonnenbühl': 'Germany',
    'Perugia': 'Italy',
    'Tenerife': 'Spain',
    'Catalunya.': 'Spain',
    'Republic of Moldova': 'Moldova',
    'AT': 'Austria',
    'Austria.': 'Austria',
    'Nijkerk.': 'Netherlands',
    'Noord Brabant': 'Netherlands',
    'Kenya': 'Kenya',
    'France / Rwanda': 'France/Rwanda',  # Combined two locations
    'Rwanda': 'Rwanda',
    'Golden Bay': 'New Zealand',
    'Wellington': 'New Zealand',
    'Saudi Arabia': 'Saudi Arabia',
    'United States': 'United States',
    'nan': 'Unknown',  # Placeholder for missing data
    'Unknown': 'Unknown',
    'Namibia': 'Namibia',
    'Country Not Found': 'Unknown',
    'Guatemala': 'Guatemala',
    'Singapore': 'Singapore',
}

# %%
# map location_country_dict to country column in df_final dataframe to create country_clean column

df_final['country_clean'] = df_final['country'].map(location_country_dict)
df_final.head(25)
df_final = df_final[['year', 'name', 'age', 'country_clean', 'location', 'bike', 'bags', 'gear', 'race', 'link', 'source']]
